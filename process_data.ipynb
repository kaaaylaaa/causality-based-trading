# %%
import pandas as pd
historical_data = pd.read_csv('data/Cleaned_SP500_Data_latest.csv')
# print(historical_data)
diff_data = historical_data.diff()
# print(diff_data)
diff_data = diff_data.loc[1:,:]
print(diff_data)
diff_data.to_csv('data/Cleaned_SP500_Data_latest_diff.csv', index = False)
# Out:
#            MMM       PSA       ELV      SWKS       CRM      EXPE      CSCO  \
# 1     0.187485  0.776634  0.000000  0.268518  0.259254 -0.009438 -0.014396
# 2    -0.480370 -0.053581 -1.167671 -0.075521 -0.887459 -0.226189  0.021583
# 3     0.011688 -0.113838  1.556900  0.134262  0.717945  2.346893  0.215858
# 4    -0.597534  0.180801  0.986000  0.109085  1.984314 -1.074478 -0.014393
# 5    -0.105469  1.954956  0.674706 -0.167826 -0.648140 -0.716324 -0.143898
# ...        ...       ...       ...       ...       ...       ...       ...
# 2674  0.029839  3.669983 -0.309998  0.725281  2.470001  4.420013  0.520000
# 2675  0.616669  2.470001 -0.350037 -1.130005 -3.540009 -1.940002  0.260002
# 2676  1.521797  2.240021 -0.699951  1.650002 -0.750000 -0.330002  0.209999
# 2677 -0.626618  5.449982  0.979980 -2.690002 -2.500000 -0.070007 -0.230000
# 2678  1.939545  7.700012  2.640015  4.029999  5.410004  5.010010  0.520000
#
# ...

# %%
import pandas as pd
historical_data = pd.read_csv('data/Cleaned_S_P_500_Data.csv')
daily_returns = historical_data.pct_change()
daily_returns = daily_returns.loc[1:,:]
print(daily_returns.head())
daily_returns.to_csv('data/sp500_return.csv', index = False)
# Out:
#           A       AAP      AAPL       ABC      ABMD       ABT       ACN  \
# 1 -0.024371 -0.000963 -0.000714 -0.008962 -0.003764 -0.002660  0.003613
# 2  0.002776  0.002892  0.008294  0.006188 -0.013854  0.001333  0.032403
# 3  0.022539 -0.010091  0.022576  0.007096  0.001277  0.012650  0.008137
# 4  0.021268  0.007282  0.015384 -0.005636 -0.003827  0.006136 -0.005477
# 5  0.028020  0.001205 -0.010351  0.012282  0.039693  0.009802  0.007246
#
#        ADBE       ADI       ADM  ...       XEC       XEL      XLNX       XOM  \
# 1 -0.003215 -0.007205 -0.016768  ... -0.023219 -0.008638 -0.014319 -0.003362
# 2  0.015806  0.021408  0.016691  ... -0.002431  0.005126  0.005155  0.001173
# 3  0.017783  0.023091  0.031763  ...  0.017601  0.000000  0.035431  0.013478
# 4  0.014353  0.017361 -0.005880  ...  0.032730 -0.003570  0.042774  0.021249
# 5  0.008920 -0.000683 -0.001392  ...  0.009276 -0.006141  0.010794 -0.002123
#
#        XRAY       XRX       YUM       ZBH      ZBRA      ZION
# ...

# %%
import pandas as pd
data = pd.read_csv('data/csi300_return.csv')
length = int(len(data)*0.8)
train_data = data.loc[:length, :]
print(train_data)
train_data.to_csv('data/csi300_return_80.csv', index = False)
# Out:
#              1         2        63       100       157       301       338  \
# 0     0.044211  0.018200  0.000000 -0.005865  0.011792 -0.001842 -0.001764
# 1     0.040827  0.090367  0.026239  0.035398  0.065268  0.047970  0.054027
# 2     0.003874  0.017304  0.013068  0.000000  0.028446  0.019366  0.017006
# 3     0.003859 -0.004476  0.021312  0.008547 -0.008511  0.020725  0.010363
# 4     0.007208  0.027878  0.013729  0.002825  0.043348  0.005076  0.046853
# ...        ...       ...       ...       ...       ...       ...       ...
# 2005  0.023077  0.003905  0.040524  0.012048 -0.006803  0.000000 -0.047736
# 2006  0.000000  0.005835 -0.025773 -0.028571 -0.031963  0.000000 -0.006427
# 2007 -0.016541 -0.008379  0.016167  0.014706  0.002358  0.000000 -0.011643
# 2008 -0.019113 -0.026649 -0.020538 -0.024155  0.000000  0.000000 -0.006545
# 2009  0.020265 -0.004341  0.042823  0.014851  0.000000  0.000000  0.010540
#
# ...

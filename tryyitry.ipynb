# %%
import pandas as pd
data = pd.read_csv('./data/Cleaned_S_P_500_Data.csv', delimiter=',', index_col=False, header=0)

# %%
data
# Out:
#           A     AAP     AAPL    ABC    ABMD    ABT     ACN    ADBE     ADI  \
# 0     25.85   41.54  165.298  21.20    7.97  45.12   33.21   31.10   27.76
# 1     25.22   41.50  165.180  21.01    7.94  45.00   33.33   31.00   27.56
# 2     25.29   41.62  166.550  21.14    7.83  45.06   34.41   31.49   28.15
# 3     25.86   41.20  170.310  21.29    7.84  45.63   34.69   32.05   28.80
# 4     26.41   41.50  172.930  21.17    7.81  45.91   34.50   32.51   29.30
# ...     ...     ...      ...    ...     ...    ...     ...     ...     ...
# 2599  85.30  160.57  284.270  85.42  172.30  87.28  211.61  329.64  119.72
# 2600  85.45  159.27  289.910  85.05  171.01  87.28  212.05  331.20  119.73
# 2601  85.42  158.35  289.800  84.91  169.27  87.40  212.22  330.79  119.45
# 2602  84.90  159.12  291.520  83.64  167.29  86.80  210.64  328.34  118.86
# 2603  85.31  160.16  293.650  85.02  170.59  86.86  210.57  329.81  118.84
#
#         ADM  ...    XEC     XEL   XLNX    XOM   XRAY    XRX     YUM     ZBH  \
# 0     28.03  ...  37.90  19.680  21.65  68.41  33.01   8.46   33.72   46.60
# 1     27.56  ...  37.02  19.510  21.34  68.18  32.89   8.34   33.36   46.24
# 2     28.02  ...  36.93  19.610  21.45  68.26  33.02   8.43   33.57   47.44
# 3     28.91  ...  37.58  19.610  22.21  69.18  33.46   8.64   34.04   49.11
# 4     28.74  ...  38.81  19.540  23.16  70.65  33.50   8.64   34.19   48.95
# ...     ...  ...    ...     ...    ...    ...    ...    ...     ...     ...
# 2599  46.08  ...  52.56  62.860  98.49  70.02  57.21  37.37  100.33  150.87
# 2600  46.20  ...  52.24  62.790  98.68  70.13  56.53  37.48  101.79  150.30
# 2601  46.30  ...  51.91  63.115  98.42  69.89  56.84  37.31  101.90  150.01
# 2602  46.12  ...  51.85  63.290  97.68  69.48  56.40  36.90  100.64  148.75
# 2603  46.35  ...  52.49  63.490  97.77  69.78  56.59  36.87  100.73  149.68
#
#         ZBRA   ZION
# 0      24.95  16.43
# 1      24.98  16.28
# 2      25.27  16.39
# 3      25.62  16.74
# 4      25.92  16.07
# ...      ...    ...
# 2599  254.33  51.53
# 2600  254.42  51.66
# 2601  256.00  51.50
# 2602  254.11  51.77
# 2603  255.44  51.92
#
# [2604 rows x 446 columns]

# %%
import numpy as np
import pandas as pd
import networkx as nx
import graphviz
import lingam
from lingam.utils import make_dot, print_causal_directions, print_dagc
from os import listdir
from os.path import isfile, join
import statistics

# %%
# first_200_columns = data.iloc[:, :200]
model = lingam.VARLiNGAM(lags=3)
model.fit(data)

# %%
# print(len(model.adjacency_matrices_))
df = pd.DataFrame(model.adjacency_matrices_[2])
df.to_csv('adjacencymatrix2.csv', index=False, header=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[37], line 2
#       1 # print(len(model.adjacency_matrices_))
# ----> 2 df = pd.DataFrame(model.adjacency_matrices_[2])
#       3 df.to_csv('adjacencymatrix2.csv', index=False, header=False)
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
summary_matrix = np.sum(model.adjacency_matrices_, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 summary_matrix = np.sum(model.adjacency_matrices_, axis=0)
#
# NameError: name 'np' is not defined

# %%
model = lingam.VARLiNGAM(lags=5)
model.fit(new_data)
# summary_matrix = np.sum(model.adjacency_matrices_, axis=0)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[17], line 2
#       1 model = lingam.VARLiNGAM(lags=5)
# ----> 2 model.fit(new_data)
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/lingam/var_lingam.py:94, in VARLiNGAM.fit(self, X)
#      91 M_taus = self._ar_coefs
#      93 if M_taus is None:
# ---> 94     M_taus, lags, residuals = self._estimate_var_coefs(X)
#      95 else:
#      96     lags = M_taus.shape[0]
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/lingam/var_lingam.py:325, in VARLiNGAM._estimate_var_coefs(self, X)
#     322 var = VAR(X)
#     323 fitted = var.fit(maxlags=lag, ic=None, trend="n")
# --> 325 value = getattr(fitted, self._criterion)
#     326 if value < min_value:
#     327     min_value = value
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/statsmodels/base/wrapper.py:34, in ResultsWrapper.__getattribute__(self, attr)
#      31 except AttributeError:
#      32     pass
# ---> 34 obj = getattr(results, attr)
#      35 data = results.model.data
#      36 how = self._wrap_attrs.get(attr)
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/statsmodels/tsa/vector_ar/var_model.py:2326, in VARResults.bic(self)
#    2323 @property
#    2324 def bic(self):
#    2325     """Bayesian a.k.a. Schwarz info criterion"""
# -> 2326     return self.info_criteria["bic"]
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/statsmodels/tsa/vector_ar/var_model.py:2289, in VARResults.info_criteria(self)
#    2287 free_params = lag_order * neqs ** 2 + neqs * self.k_exog
#    2288 if self.df_resid:
# -> 2289     ld = logdet_symm(self.sigma_u_mle)
#    2290 else:
#    2291     ld = -np.inf
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/statsmodels/tools/linalg.py:28, in logdet_symm(m, check_symm)
#      26     if not np.all(m == m.T):  # would be nice to short-circuit check
#      27         raise ValueError("m is not symmetric.")
# ---> 28 c, _ = linalg.cho_factor(m, lower=True)
#      29 return 2*np.sum(np.log(c.diagonal()))
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/scipy/linalg/_decomp_cholesky.py:154, in cho_factor(a, lower, overwrite_a, check_finite)
#      94 def cho_factor(a, lower=False, overwrite_a=False, check_finite=True):
#      95     """
#      96     Compute the Cholesky decomposition of a matrix, to use in cho_solve
#      97
#    (...)
#     152
#     153     """
# --> 154     c, lower = _cholesky(a, lower=lower, overwrite_a=overwrite_a, clean=False,
#     155                          check_finite=check_finite)
#     156     return c, lower
#
# File ~/anaconda3/envs/l/lib/python3.12/site-packages/scipy/linalg/_decomp_cholesky.py:37, in _cholesky(a, lower, overwrite_a, clean, check_finite)
#      35 c, info = potrf(a1, lower=lower, overwrite_a=overwrite_a, clean=clean)
#      36 if info > 0:
# ---> 37     raise LinAlgError("%d-th leading minor of the array is not positive "
#      38                       "definite" % info)
#      39 if info < 0:
#      40     raise ValueError('LAPACK reported an illegal value in {}-th argument'
#      41                      'on entry to "POTRF".'.format(-info))
#
# LinAlgError: 98-th leading minor of the array is not positive definite

# %% [raw]
# first_10_columns = data.iloc[:, :50]
# model = lingam.VARLiNGAM(lags=1)
# model.fit(first_10_columns)

# %% [raw]
# print(model.adjacency_matrices_)
